# %%
# %load_ext autoreload
# %autoreload 2

import os

os.environ["KERAS_BACKEND"] = "jax"

# %%
import bayesflow as bf
import keras

class CustomTimeSeriesNetwork(bf.networks.TimeSeriesNetwork):
    def call(self, x, training=False, **kwargs):
        x = super().call(x, training=training, **kwargs)
        self.add_loss(keras.ops.sum(x**2))
        return x

workflow = bf.BasicWorkflow(
    inference_network=bf.networks.CouplingFlow(),
    summary_network=CustomTimeSeriesNetwork(),
    inference_variables=["parameters"],
    summary_variables=["observables"],
    simulator=bf.simulators.SIR()
)

history = workflow.fit_online(epochs=15, batch_size=32, num_batches_per_epoch=200)

diagnostics = workflow.plot_default_diagnostics(test_data=300)
# Out:
# INFO:bayesflow:Using backend 'jax'
# 2025-07-22 13:16:17.567566: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753182977.583159  574880 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753182977.586855  574880 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO:bayesflow:Fitting on dataset instance of OnlineDataset.
# INFO:bayesflow:Building on a test batch.
# Epoch 1/15
#  52/200 ━━━━━━━━━━━━━━━━━━━━ 12s 86ms/step - loss: 2.8519
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 18
#       8         return x
#      10 workflow = bf.BasicWorkflow(
#      11     inference_network=bf.networks.CouplingFlow(),
#      12     summary_network=CustomTimeSeriesNetwork(),
#    (...)
#      15     simulator=bf.simulators.SIR()
#      16 )
# ---> 18 history = workflow.fit_online(epochs=15, batch_size=32, num_batches_per_epoch=200)
#      20 diagnostics = workflow.plot_default_diagnostics(test_data=300)
#
# File ~/code/bayesflow/bayesflow/workflows/basic_workflow.py:789, in BasicWorkflow.fit_online(self, epochs, num_batches_per_epoch, batch_size, keep_optimizer, validation_data, augmentations, **kwargs)
#     741 """
#     742 Train the approximator using an online data-generating process. The dataset is dynamically generated during
#     743 training, making this approach suitable for scenarios where generating new simulations is computationally cheap.
#    (...)
#     778     metric evolution over epochs.
#     779 """
#     781 dataset = OnlineDataset(
#     782     simulator=self.simulator,
#     783     batch_size=batch_size,
#    (...)
#     786     augmentations=augmentations,
#     787 )
# --> 789 return self._fit(
#     790     dataset, epochs, strategy="online", keep_optimizer=keep_optimizer, validation_data=validation_data, **kwargs
#     791 )
#
# File ~/code/bayesflow/bayesflow/workflows/basic_workflow.py:964, in BasicWorkflow._fit(self, dataset, epochs, strategy, keep_optimizer, validation_data, **kwargs)
#     961     self.approximator.compile(optimizer=self.optimizer, metrics=kwargs.pop("metrics", None))
#     963 try:
# --> 964     self.history = self.approximator.fit(
#     965         dataset=dataset, epochs=epochs, validation_data=validation_data, **kwargs
#     966     )
#     967     self._on_training_finished()
#     968     return self.history
#
# File ~/code/bayesflow/bayesflow/approximators/continuous_approximator.py:322, in ContinuousApproximator.fit(self, *args, **kwargs)
#     270 def fit(self, *args, **kwargs):
#     271     """
#     272     Trains the approximator on the provided dataset or on-demand data generated from the given simulator.
#     273     If `dataset` is not provided, a dataset is built from the `simulator`.
#    (...)
#     320         If both `dataset` and `simulator` are provided or neither is provided.
#     321     """
# --> 322     return super().fit(*args, **kwargs, adapter=self.adapter)
#
# File ~/code/bayesflow/bayesflow/approximators/approximator.py:139, in Approximator.fit(self, dataset, simulator, **kwargs)
#     136     mock_data_shapes = keras.tree.map_structure(keras.ops.shape, mock_data)
#     137     self.build(mock_data_shapes)
# --> 139 return super().fit(dataset=dataset, **kwargs)
#
# File ~/code/bayesflow/bayesflow/approximators/backend_approximators/backend_approximator.py:20, in BackendApproximator.fit(self, dataset, **kwargs)
#      19 def fit(self, *, dataset: keras.utils.PyDataset, **kwargs):
# ---> 20     return super().fit(x=dataset, y=None, **filter_kwargs(kwargs, super().fit))
#
# File ~/programs/anaconda3/envs/bayesflow/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/programs/anaconda3/envs/bayesflow/lib/python3.11/site-packages/keras/src/backend/jax/trainer.py:418, in JAXTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     409     state = self._get_jax_state(
#     410         trainable_variables=True,
#     411         non_trainable_variables=True,
#    (...)
#     414         purge_model_variables=True,
#     415     )
#     416     self._jax_state_synced = False
# --> 418 logs, state = self.train_function(state, iterator)
#     419 (
#     420     trainable_variables,
#     421     non_trainable_variables,
#     422     optimizer_variables,
#     423     metrics_variables,
#     424 ) = state
#     426 # Setting _jax_state enables callbacks to force a state sync
#     427 # if they need to.
#
# File ~/programs/anaconda3/envs/bayesflow/lib/python3.11/site-packages/keras/src/backend/jax/trainer.py:266, in JAXTrainer._make_function.<locals>.iterator_step(state, iterator)
#     265 def iterator_step(state, iterator):
# --> 266     return step_function(state, next(iterator))
#
# File ~/programs/anaconda3/envs/bayesflow/lib/python3.11/site-packages/keras/src/backend/jax/trainer.py:1059, in JAXEpochIterator._prefetch_numpy_iterator(self, numpy_iterator)
#    1057 while queue:
#    1058     yield queue.popleft()
# -> 1059     enqueue(1)
#
# File ~/programs/anaconda3/envs/bayesflow/lib/python3.11/site-packages/keras/src/backend/jax/trainer.py:1053, in JAXEpochIterator._prefetch_numpy_iterator.<locals>.enqueue(n)
#    1052 def enqueue(n=2):
# -> 1053     for data in itertools.islice(numpy_iterator, n):
#    1054         queue.append(_distribute_data(data))
#
# File ~/programs/anaconda3/envs/bayesflow/lib/python3.11/site-packages/keras/src/trainers/data_adapters/data_adapter_utils.py:198, in get_jax_iterator(iterable)
#     195     else:
#     196         return np.asarray(x)
# --> 198 for batch in iterable:
#     199     yield tree.map_structure(convert_to_jax_compatible, batch)
#
# File ~/programs/anaconda3/envs/bayesflow/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:248, in PyDatasetAdapter._finite_generator(self)
#     245     random.shuffle(indices)
#     247 for i in indices:
# --> 248     yield self._standardize_batch(self.py_dataset[i])
#
# File ~/code/bayesflow/bayesflow/datasets/online_dataset.py:74, in OnlineDataset.__getitem__(self, item)
#      60 def __getitem__(self, item: int) -> dict[str, np.ndarray]:
#      61     """
#      62     Generate one batch of data.
#      63
#    (...)
#      72         A batch of simulated (and optionally augmented/adapted) data.
#      73     """
# ---> 74     batch = self.simulator.sample((self.batch_size,))
#      76     if self.augmentations is None:
#      77         pass
#
# File ~/code/bayesflow/bayesflow/utils/decorators.py:63, in alias.<locals>.alias_wrapper.<locals>.wrapper(*args, **kwargs)
#      60 matches = [name for name in kwargs if name in aliases]
#      62 if not matches:
# ---> 63     return fn(*args, **kwargs)
#      65 if len(matches) > 1 or (len(matches) > 0 and len(args) > argpos):
#      66     raise TypeError(
#      67         f"{fn.__name__}() got multiple values for argument {argname!r}.\n"
#      68         f"This argument is also aliased as {aliases!r}"
#      69     )
#
# File ~/code/bayesflow/bayesflow/utils/decorators.py:95, in argument_callback.<locals>.callback_wrapper.<locals>.wrapper(*args, **kwargs)
#      92     args = list(args)
#      93     args[argpos] = callback(args[argpos])
# ---> 95 return fn(*args, **kwargs)
#
# File ~/code/bayesflow/bayesflow/simulators/benchmark_simulators/benchmark_simulator.py:27, in BenchmarkSimulator.sample(self, batch_shape, **kwargs)
#      11 @allow_batch_size
#      12 def sample(self, batch_shape: Shape, **kwargs) -> dict[str, np.ndarray]:
#      13     """Runs simulated benchmark and returns `batch_size` parameter
#      14     and observation batches
#      15
#    (...)
#      24         with shapes (`batch_size`, ...)
#      25     """
# ---> 27     data = batched_call(self, batch_shape, kwargs=kwargs, flatten=True)
#      28     data = tree_stack(data, axis=0, numpy=True)
#      29     return data
#
# File ~/code/bayesflow/bayesflow/utils/functional.py:54, in batched_call(f, batch_shape, args, kwargs, map_predicate, flatten)
#      51     map_args = [arg[index] if map_predicate(arg) else arg for arg in args]
#      52     map_kwargs = {key: value[index] if map_predicate(value) else value for key, value in kwargs.items()}
# ---> 54     outputs[index] = f(*map_args, **map_kwargs)
#      56 if flatten:
#      57     outputs = outputs.flatten()
#
# File ~/code/bayesflow/bayesflow/simulators/benchmark_simulators/benchmark_simulator.py:39, in BenchmarkSimulator.__call__(self, **kwargs)
#      37 def __call__(self, **kwargs) -> dict[str, np.ndarray]:
#      38     prior_draws = self.prior()
# ---> 39     observables = self.observation_model(prior_draws)
#      40     return dict(parameters=prior_draws.astype(np.float32), observables=observables.astype(np.float32))
#
# File ~/code/bayesflow/bayesflow/simulators/benchmark_simulators/sir.py:107, in SIR.observation_model(self, params)
#     104 t_vec = np.linspace(0, self.T, self.T)
#     106 # Integrate using scipy and retain only infected (2-nd dimension)
# --> 107 irt = odeint(self._deriv, x0, t_vec, args=(self.N, beta, gamma))[:, 1]
#     109 # Subsample evenly the specified number of points, if specified
#     110 if self.subsample is not None:
#
# File ~/programs/anaconda3/envs/bayesflow/lib/python3.11/site-packages/scipy/integrate/_odepack_py.py:247, in odeint(func, y0, t, args, Dfun, col_deriv, full_output, ml, mu, rtol, atol, tcrit, h0, hmax, hmin, ixpr, mxstep, mxhnil, mxordn, mxords, printmessg, tfirst)
#     245 t = copy(t)
#     246 y0 = copy(y0)
# --> 247 output = _odepack.odeint(func, y0, t, args, Dfun, col_deriv, ml, mu,
#     248                          full_output, rtol, atol, tcrit, h0, hmax, hmin,
#     249                          ixpr, mxstep, mxhnil, mxordn, mxords,
#     250                          int(bool(tfirst)))
#     251 if output[-1] < 0:
#     252     warning_msg = (f"{_msgs[output[-1]]} Run with full_output = 1 to "
#     253                    f"get quantitative information.")
#
# File ~/code/bayesflow/bayesflow/simulators/benchmark_simulators/sir.py:60, in SIR._deriv(self, x, t, N, beta, gamma)
#      57     if self.rng is None:
#      58         self.rng = np.random.default_rng()
# ---> 60 def _deriv(self, x, t, N, beta, gamma):
#      61     """Helper function for scipy.integrate.odeint."""
#      63     s, i, r = x
#
# KeyboardInterrupt:

# %%
workflow.approximator.summary_network.losses
